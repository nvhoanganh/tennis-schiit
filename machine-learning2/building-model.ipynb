# %% [markdown]
# **Match outcome prediction**
#
# https://www.kaggle.com/harvinderwazir/match-outcome-prediction-in-football

# %%
## import required libraries
import numpy as np
import pandas as pd
pd.__version__
# Out:
# '1.0.1'

# %% [markdown]
# * read raw data from the endpoint

# %%
results_dataframe = pd.read_csv("https://tennisscoresheet.com/api/results/trainingdata.csv", sep=",")
results_dataframe.describe()
# Out:
#           groupId        team1        team2   headStart   WinOrLose
# count  120.000000   120.000000   120.000000  120.000000  120.000000
# mean     0.625000   639.375000   638.916667   -0.057083    0.500000
# std      1.013045  1006.251393  1007.674689    0.330221    0.502096
# min      0.000000     0.000000     0.000000   -2.000000    0.000000
# 25%      0.000000    18.000000    17.000000    0.000000    0.000000
# 50%      0.000000    30.000000    32.000000    0.000000    0.500000
# 75%      1.000000  1000.000000  1002.000000    0.000000    1.000000
# max      3.000000  3012.000000  3012.000000    1.000000    1.000000

# %%
results_dataframe.head()
# Out:
#   groupName  groupId  team1              team1Name  team2  \
# 0       HSV        0     18     Hoang Anh;Tuan Xiu     26
# 1       HSV        0     27     Cuong;Thang Nguyen     20
# 2       HSV        0      9   Bill Nguyen;Tuan Xiu     25
# 3       HSV        0     18     Hoang Anh;Tuan Xiu     16
# 4       HSV        0      5  Hoang Anh;Bill Nguyen     28
#
#                  team2Name                 matchDate  isBagel score  \
# 0    Tuan Nhu;Thang Nguyen  2020-03-11T00:00:00.000Z    False   6:2
# 1        Tuan Nhu;Tuan Xiu  2020-03-11T00:00:00.000Z    False   6:4
# 2   Hoang Anh;Thang Nguyen  2020-03-11T00:00:00.000Z    False   6:2
# 3  Thang Nguyen;Dan Nguyen  2020-03-11T00:00:00.000Z    False   6:3
# 4    Tuan Xiu;Thang Nguyen  2020-03-11T00:00:00.000Z    False   6:4
#
#    headStart  WinOrLose
# 0        0.0          1
# 1        0.0          1
# 2        0.0          1
# 3        0.0          1
# 4        0.0          1

# %%
results_dataframe.hist('team1')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024142BEDFD0>]],
#       dtype=object)
